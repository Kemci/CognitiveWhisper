# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %% [markdown]
# ## LOAD DATASET

# %%
#dataset link -- https://tinyurl.com/zfspxpyy
X_train = np.loadtxt(r'C:\Users\Kemci\Desktop\CNN Image Classifier (Dogs & Cats)\Image Classification CNN Keras Dataset\input.csv', delimiter = ',')
Y_train = np.loadtxt(r'C:\Users\Kemci\Desktop\CNN Image Classifier (Dogs & Cats)\Image Classification CNN Keras Dataset\labels.csv', delimiter = ',')

X_test = np.loadtxt(r'C:\Users\Kemci\Desktop\CNN Image Classifier (Dogs & Cats)\Image Classification CNN Keras Dataset\input_test.csv', delimiter = ',')
Y_test = np.loadtxt(r'C:\Users\Kemci\Desktop\CNN Image Classifier (Dogs & Cats)\Image Classification CNN Keras Dataset\labels_test.csv', delimiter = ',')

# %%
X_train = X_train.reshape(len(X_train), 100, 100, 3)
Y_train = Y_train.reshape(len(Y_train), 1)

X_test = X_test.reshape(len(X_test), 100, 100, 3)
Y_test = Y_test.reshape(len(Y_test), 1)

X_train = X_train/255.0
X_test = X_test/255.0

# %%
print ("Shape of X_train: ", X_train.shape)
print ("Shape of Y_train: ", Y_train.shape)
print ("Shape of X_test: ", X_test.shape)
print ("Shape of X_test: ", X_train.shape)
# Out:
# Shape of X_train:  (2000, 100, 100, 3)
# Shape of Y_train:  (2000, 1)
# Shape of X_test:  (400, 100, 100, 3)
# Shape of X_test:  (2000, 100, 100, 3)

# %%
idx = random.randint(0, len(X_train))
plt.imshow(X_train[idx, :]) 
plt.show()

# %% [markdown]
# ## MODEL

# %%
model = Sequential ([
    Conv2D (32, (3, 3), activation = 'relu', input_shape = (100, 100, 3)),
    MaxPooling2D((2, 2)),

    Conv2D (32, (3, 3), activation = 'relu'),
    MaxPooling2D((2, 2)),

    Flatten(),
    Dense (64, activation = 'relu'),
    Dense (1, activation = 'sigmoid')
])
# Out:
# c:\Users\Kemci\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
model = Sequential()
model.add(Conv2D (32, (3, 3), activation = 'relu', input_shape = (100, 100, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D (32, (3, 3), activation = 'relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())
model.add(Dense (64, activation = 'relu'))
model.add(Dense (1, activation = 'sigmoid'))

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
model.fit(X_train, Y_train, epochs = 5, batch_size = (64))
# Out:
# Epoch 1/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - accuracy: 0.9483 - loss: 0.1680
# Epoch 2/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - accuracy: 0.9512 - loss: 0.1430
# Epoch 3/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 202ms/step - accuracy: 0.9763 - loss: 0.1086
# Epoch 4/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 229ms/step - accuracy: 0.9600 - loss: 0.1152
# Epoch 5/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - accuracy: 0.9832 - loss: 0.0747

# %%
model.evaluate(X_test, Y_test)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.4967 - loss: 0.8454
# [0.6367901563644409, 0.6474999785423279]

# %% [markdown]
# ## PREDICTIONS

# %%
idx2 = random.randint(0, len(Y_test))
plt.imshow(X_test[idx2, :])
plt.show()

y_pred = model.predict(X_test[idx2, :].reshape(1, 100, 100, 3))
print(y_pred)

y_pred = y_pred > 0.5
if (y_pred == 0):
    pred = 'dog'
else:
    pred = 'cat'
print("The model says this is a: ", pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [[0.87956285]]
# The model says this is a:  cat
